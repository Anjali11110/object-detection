# %%
# !pip install ultralytics

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/pizza_burger.jpg"
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/pizza_burger.jpg: 448x640 1 sandwich, 1 pizza, 1 dining table, 439.7ms
# Speed: 18.1ms preprocess, 439.7ms inference, 3.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict5
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image("/content/runs/detect/predict5/pizza_burger.jpg",width=800,height=700)

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/drive/MyDrive/Colab Notebooks/car_vedio.mp4"
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (1/786) /content/drive/MyDrive/Colab Notebooks/car_vedio.mp4: 384x640 1 truck, 313.2ms
# video 1/1 (2/786) /content/drive/MyDrive/Colab Notebooks/car_vedio.mp4: 384x640 (no detections), 192.9ms
# video 1/1 (3/786) /content/drive/MyDrive/Colab Notebooks/car_vedio.mp4: 384x640 1 truck, 163.8ms
# video 1/1 (4/786) /content/drive/MyDrive/Colab Notebooks/car_vedio.mp4: 384x640 1 truck, 159.4ms
# video 1/1 (5/786) /content/drive/MyDrive/Colab Notebooks/car_vedio.mp4: 384x640 1 truck, 239.6ms
# video 1/1 (6/786) /content/drive/MyDrive/Colab Notebooks/car_vedio.mp4: 384x640 1 truck, 169.1ms
# video 1/1 (7/786) /content/drive/MyDrive/Colab Notebooks/car_vedio.mp4: 384x640 1 truck, 246.3ms
# video 1/1 (8/786) /content/drive/MyDrive/Colab Notebooks/car_vedio.mp4: 384x640 1 truck, 224.8ms
# ...

# %%
# !ffmpeg -i "/content/runs/detect/predict3/car_video.avi" -c:v libx264 "final.mp4"

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/donut.jpg"
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.1.0+cu121 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/1 /content/donut.jpg: 640x448 9 donuts, 202.4ms
# Speed: 6.9ms preprocess, 202.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 448)
# Results saved to runs/detect/predict7
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from IPython.display import Image
Image("/content/runs/detect/predict7/donut.jpg",width=800,height=700)
